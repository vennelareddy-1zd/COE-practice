# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv(r"C:\Users\DELL\Downloads\Advertising.csv")
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
#step1: independent and dependent variable creation
X=data[['TV']] #contains a feature
y=data.Sales  #target

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=4)

# %%
print(len(X_test))
print(len(X_train))
# Out:
# 40
# 160

# %%
#step3: creating a model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() #object creation
LR.fit(X_train,y_train) #training of linear regression
y_predict=LR.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error #to check the performance
r2score=r2_score(y_test,y_predict)
r2score #coefficient of determination
# Out:
# 0.46138746336817515

# %%
print("MSE: ",mean_squared_error(y_test,y_predict))
print("MAE: ",mean_absolute_error(y_test,y_predict))
print("RMSE: ",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE:  13.06226628830567
# MAE:  2.990565035759226
# RMSE:  3.6141757412037494

# %% [markdown]
# The data is divided into x and y parts where the y column is called labelled data becoz they are labels for all the inputs in the x.
#   x       y
# x_train  y_train
# x_test   y_test
# test_size=0.2 means it takes 20% for testing and other 80% is for training.
# the prediction y_pred is compared to y_test.
#
# train test split:
# It is a cross validation technique.
# To avoid the overfitting.
# It is called as hold out method.

# %% [markdown]
# For the 'Radio' column :

# %%
X=data[['Radio']]
y=data.Sales

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=4)

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression() 
LR.fit(X_train,y_train) 
y_predict=LR.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error 
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.37864501183785726

# %%
print("MSE: ",mean_squared_error(y_test,y_predict))
print("MAE: ",mean_absolute_error(y_test,y_predict))
print("RMSE: ",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE:  15.068910882943161
# MAE:  3.268917036469783
# RMSE:  3.881869508747449

# %% [markdown]
# For the 'Newspaper' column :

# %%
X=data[['Newspaper']]
y=data.Sales

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=4)

from sklearn.linear_model import LinearRegression
LR=LinearRegression() 
LR.fit(X_train,y_train) 
y_predict=LR.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error 
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# -0.11728796161004928

# %%
print("MSE: ",mean_squared_error(y_test,y_predict))
print("MAE: ",mean_absolute_error(y_test,y_predict))
print("RMSE: ",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE:  27.09612547552867
# MAE:  3.992290912504232
# RMSE:  5.205393882841976
